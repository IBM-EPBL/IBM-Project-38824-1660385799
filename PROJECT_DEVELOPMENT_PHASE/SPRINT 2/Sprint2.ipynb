# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv("test_data.csv")

# %%
df
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318439             21                  c                   3
# 1        318440             29                  a                   4
# 2        318441             26                  b                   2
# 3        318442              6                  a                   6
# 4        318443             28                  b                  11
# ...         ...            ...                ...                 ...
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                         Z                                  3    gynecology
# 1                         X                                  2    gynecology
# 2                         Y                                  3    gynecology
# 3                         X                                  3    gynecology
# 4                         X                                  2    gynecology
# ...                     ...                                ...           ...
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0              S                  A        2.0      17006                2.0
# 1              S                  F        2.0      17006                2.0
# 2              Q                  D        4.0      17006                2.0
# 3              Q                  F        2.0      17006                2.0
# 4              R                  F        2.0      17006                2.0
# ...          ...                ...        ...        ...                ...
# 137052         Q                  D        3.0      41160                3.0
# 137053         R                  E        4.0      30985                7.0
# 137054         R                  A        4.0      81811               12.0
# 137055         R                  E        4.0      57021               10.0
# 137056         Q                  F        4.0     126729                3.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0              Emergency            Moderate                      2  71-80
# 1                 Trauma            Moderate                      4  71-80
# 2              Emergency            Moderate                      3  71-80
# 3                 Trauma            Moderate                      3  71-80
# 4                 Trauma            Moderate                      4  71-80
# ...                  ...                 ...                    ...    ...
# 137052         Emergency               Minor                      4  41-50
# 137053         Emergency            Moderate                      2   0-10
# 137054            Urgent               Minor                      2   0-10
# 137055            Trauma               Minor                      2  41-50
# 137056            Trauma             Extreme                      5  51-60
#
#         Admission_Deposit
# 0                  3095.0
# 1                  4018.0
# 2                  4492.0
# 3                  4173.0
# 4                  4161.0
# ...                   ...
# 137052             6313.0
# 137053             3510.0
# 137054             7190.0
# 137055             5435.0
# 137056             4702.0
#
# [137057 rows x 17 columns]

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# 1         S                  F        2.0      17006                2.0
# 2         Q                  D        4.0      17006                2.0
# 3         Q                  F        2.0      17006                2.0
# 4         R                  F        2.0      17006                2.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                      2  71-80
# 1            Trauma            Moderate                      4  71-80
# 2         Emergency            Moderate                      3  71-80
# 3            Trauma            Moderate                      3  71-80
# 4            Trauma            Moderate                      4  71-80
#
#    Admission_Deposit
# 0             3095.0
# 1             4018.0
# 2             4492.0
# 3             4173.0
# 4             4161.0

# %%
df.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 137052         Q                  D        3.0      41160                3.0
# 137053         R                  E        4.0      30985                7.0
# 137054         R                  A        4.0      81811               12.0
# 137055         R                  E        4.0      57021               10.0
# 137056         Q                  F        4.0     126729                3.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 137052         Emergency               Minor                      4  41-50
# 137053         Emergency            Moderate                      2   0-10
# 137054            Urgent               Minor                      2   0-10
# 137055            Trauma               Minor                      2  41-50
# 137056            Trauma             Extreme                      5  51-60
#
#         Admission_Deposit
# 137052             6313.0
# 137053             3510.0
# 137054             7190.0
# 137055             5435.0
# 137056             4702.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137057 entries, 0 to 137056
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            137057 non-null  int64
#  1   Hospital_code                      137057 non-null  int64
#  2   Hospital_type_code                 137057 non-null  object
#  3   City_Code_Hospital                 137057 non-null  int64
#  4   Hospital_region_code               137057 non-null  object
#  5   Available Extra Rooms in Hospital  137057 non-null  int64
#  6   Department                         137057 non-null  object
#  7   Ward_Type                          137057 non-null  object
#  8   Ward_Facility_Code                 137057 non-null  object
#  9   Bed Grade                          137022 non-null  float64
#  10  patientid                          137057 non-null  int64
#  11  City_Code_Patient                  134900 non-null  float64
#  12  Type of Admission                  137057 non-null  object
#  13  Severity of Illness                137057 non-null  object
#  14  Visitors with Patient              137057 non-null  int64
#  15  Age                                137057 non-null  object
#  16  Admission_Deposit                  137057 non-null  float64
# dtypes: float64(3), int64(6), object(8)
# memory usage: 17.8+ MB

# %%
df.dtypes
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                    object
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                   object
# Admission_Deposit                    float64
# dtype: object

# %%
df.shape
# Out:
# (137057, 17)

# %% [markdown]
# NULL VALUE CHECKING

# %%
df.isnull().sum().sum()
# Out:
# 2192

# %%
df.isnull()
# Out:
#         case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0         False          False               False               False
# 1         False          False               False               False
# 2         False          False               False               False
# 3         False          False               False               False
# 4         False          False               False               False
# ...         ...            ...                 ...                 ...
# 137052    False          False               False               False
# 137053    False          False               False               False
# 137054    False          False               False               False
# 137055    False          False               False               False
# 137056    False          False               False               False
#
#         Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                      False                              False       False
# 1                      False                              False       False
# 2                      False                              False       False
# 3                      False                              False       False
# 4                      False                              False       False
# ...                      ...                                ...         ...
# 137052                 False                              False       False
# 137053                 False                              False       False
# 137054                 False                              False       False
# 137055                 False                              False       False
# 137056                 False                              False       False
#
#         Ward_Type  Ward_Facility_Code  Bed Grade  patientid  \
# 0           False               False      False      False
# 1           False               False      False      False
# 2           False               False      False      False
# 3           False               False      False      False
# 4           False               False      False      False
# ...           ...                 ...        ...        ...
# 137052      False               False      False      False
# 137053      False               False      False      False
# 137054      False               False      False      False
# 137055      False               False      False      False
# 137056      False               False      False      False
#
#         City_Code_Patient  Type of Admission  Severity of Illness  \
# 0                   False              False                False
# 1                   False              False                False
# 2                   False              False                False
# 3                   False              False                False
# 4                   False              False                False
# ...                   ...                ...                  ...
# 137052              False              False                False
# 137053              False              False                False
# 137054              False              False                False
# 137055              False              False                False
# 137056              False              False                False
#
#         Visitors with Patient    Age  Admission_Deposit
# 0                       False  False              False
# 1                       False  False              False
# 2                       False  False              False
# 3                       False  False              False
# 4                       False  False              False
# ...                       ...    ...                ...
# 137052                  False  False              False
# 137053                  False  False              False
# 137054                  False  False              False
# 137055                  False  False              False
# 137056                  False  False              False
#
# [137057 rows x 17 columns]

# %%
df.describe()
# Out:
#              case_id  Hospital_code  City_Code_Hospital  \
# count  137057.000000  137057.000000       137057.000000
# mean   386967.000000      18.343747            4.758692
# std     39565.092259       8.634694            3.102245
# min    318439.000000       1.000000            1.000000
# 25%    352703.000000      11.000000            2.000000
# 50%    386967.000000      19.000000            5.000000
# 75%    421231.000000      26.000000            7.000000
# max    455495.000000      32.000000           13.000000
#
#        Available Extra Rooms in Hospital      Bed Grade      patientid  \
# count                      137057.000000  137022.000000  137057.000000
# mean                            3.192686       2.634489   65877.903515
# std                             1.164250       0.869295   37942.997623
# min                             0.000000       1.000000       3.000000
# 25%                             2.000000       2.000000   32945.000000
# 50%                             3.000000       3.000000   65786.000000
# 75%                             4.000000       3.000000   98851.000000
# max                            21.000000       4.000000  131618.000000
#
#        City_Code_Patient  Visitors with Patient  Admission_Deposit
# count      134900.000000          137057.000000      137057.000000
# mean            7.243996               3.284531        4869.731097
# std             4.790625               1.777270        1080.766723
# min             1.000000               0.000000        1800.000000
# 25%             4.000000               2.000000        4178.000000
# 50%             8.000000               3.000000        4731.000000
# 75%             8.000000               4.000000        5398.000000
# max            38.000000              32.000000       11920.000000

# %%
df.isnull().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                              35
# patientid                               0
# City_Code_Patient                    2157
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# dtype: int64

# %%
df.corr()
# Out:
#                                     case_id  Hospital_code  \
# case_id                            1.000000      -0.045982
# Hospital_code                     -0.045982       1.000000
# City_Code_Hospital                -0.012916       0.126531
# Available Extra Rooms in Hospital  0.050804      -0.056650
# Bed Grade                          0.015743      -0.017966
# patientid                          0.006000       0.004349
# City_Code_Patient                  0.075497      -0.014635
# Visitors with Patient              0.001000      -0.027404
# Admission_Deposit                 -0.040073       0.048474
#
#                                    City_Code_Hospital  \
# case_id                                     -0.012916
# Hospital_code                                0.126531
# City_Code_Hospital                           1.000000
# Available Extra Rooms in Hospital           -0.044260
# Bed Grade                                   -0.046328
# patientid                                    0.003642
# City_Code_Patient                           -0.027845
# Visitors with Patient                        0.018822
# Admission_Deposit                           -0.035529
#
#                                    Available Extra Rooms in Hospital  \
# case_id                                                     0.050804
# Hospital_code                                              -0.056650
# City_Code_Hospital                                         -0.044260
# Available Extra Rooms in Hospital                           1.000000
# Bed Grade                                                  -0.113955
# patientid                                                   0.003030
# City_Code_Patient                                          -0.006487
# Visitors with Patient                                       0.093658
# Admission_Deposit                                          -0.142906
#
#                                    Bed Grade  patientid  City_Code_Patient  \
# case_id                             0.015743   0.006000           0.075497
# Hospital_code                      -0.017966   0.004349          -0.014635
# City_Code_Hospital                 -0.046328   0.003642          -0.027845
# Available Extra Rooms in Hospital  -0.113955   0.003030          -0.006487
# Bed Grade                           1.000000  -0.001935          -0.004603
# patientid                          -0.001935   1.000000          -0.001380
# City_Code_Patient                  -0.004603  -0.001380           1.000000
# Visitors with Patient               0.090328  -0.006427          -0.013847
# Admission_Deposit                   0.066789   0.002186           0.025256
#
#                                    Visitors with Patient  Admission_Deposit
# case_id                                         0.001000          -0.040073
# Hospital_code                                  -0.027404           0.048474
# City_Code_Hospital                              0.018822          -0.035529
# Available Extra Rooms in Hospital               0.093658          -0.142906
# Bed Grade                                       0.090328           0.066789
# patientid                                      -0.006427           0.002186
# City_Code_Patient                              -0.013847           0.025256
# Visitors with Patient                           1.000000          -0.149211
# Admission_Deposit                              -0.149211           1.000000

# %%
df.isnull().sum().sum()
# Out:
# 2192

# %% [markdown]
# WORKING WITH NULL VALUES

# %%
df['Bed Grade'].fillna(df['Bed Grade'].mean(),inplace=True)

# %%
df['Bed Grade'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                               0
# patientid                               0
# City_Code_Patient                    2157
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# dtype: int64

# %%
df["City_Code_Patient"].fillna(df["City_Code_Patient"].mean(),inplace=True)

# %%
df["City_Code_Patient"].isnull().sum()
# Out:
# 0

# %% [markdown]
# AFTER PREPROCESSING

# %%
df.isnull().sum()
# Out:
# case_id                              0
# Hospital_code                        0
# Hospital_type_code                   0
# City_Code_Hospital                   0
# Hospital_region_code                 0
# Available Extra Rooms in Hospital    0
# Department                           0
# Ward_Type                            0
# Ward_Facility_Code                   0
# Bed Grade                            0
# patientid                            0
# City_Code_Patient                    0
# Type of Admission                    0
# Severity of Illness                  0
# Visitors with Patient                0
# Age                                  0
# Admission_Deposit                    0
# dtype: int64

# %% [markdown]
# TOTAL NULL VALUE CHECKING

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.cov()
# Out:
#                                         case_id  Hospital_code  \
# case_id                            1.565397e+09  -15708.921383
# Hospital_code                     -1.570892e+04      74.557947
# City_Code_Hospital                -1.585327e+03       3.389365
# Available Extra Rooms in Hospital  2.340201e+03      -0.569497
# Bed Grade                          5.413625e+02      -0.134803
# patientid                          9.006674e+06    1424.700077
# City_Code_Patient                  1.409339e+04      -0.596003
# Visitors with Patient              7.028444e+01      -0.420552
# Admission_Deposit                 -1.713558e+06     452.366177
#
#                                    City_Code_Hospital  \
# case_id                                  -1585.326728
# Hospital_code                                3.389365
# City_Code_Hospital                           9.623922
# Available Extra Rooms in Hospital           -0.159856
# Bed Grade                                   -0.124917
# patientid                                  428.732612
# City_Code_Patient                           -0.407269
# Visitors with Patient                        0.103777
# Admission_Deposit                         -119.120406
#
#                                    Available Extra Rooms in Hospital  \
# case_id                                                  2340.200582
# Hospital_code                                              -0.569497
# City_Code_Hospital                                         -0.159856
# Available Extra Rooms in Hospital                           1.355478
# Bed Grade                                                  -0.115308
# patientid                                                 133.859678
# City_Code_Patient                                          -0.035600
# Visitors with Patient                                       0.193795
# Admission_Deposit                                        -179.816014
#
#                                     Bed Grade     patientid  \
# case_id                            541.362466  9.006674e+06
# Hospital_code                       -0.134803  1.424700e+03
# City_Code_Hospital                  -0.124917  4.287326e+02
# Available Extra Rooms in Hospital   -0.115308  1.338597e+02
# Bed Grade                            0.755480 -6.380882e+01
# patientid                          -63.808819  1.439671e+09
# City_Code_Patient                   -0.018851 -2.467264e+02
# Visitors with Patient                0.139523 -4.333826e+02
# Admission_Deposit                   62.734227  8.964056e+04
#
#                                    City_Code_Patient  Visitors with Patient  \
# case_id                                 14093.392721              70.284438
# Hospital_code                              -0.596003              -0.420552
# City_Code_Hospital                         -0.407269               0.103777
# Available Extra Rooms in Hospital          -0.035600               0.193795
# Bed Grade                                  -0.018851               0.139523
# patientid                                -246.726396            -433.382569
# City_Code_Patient                          22.588897              -0.115234
# Visitors with Patient                      -0.115234               3.158688
# Admission_Deposit                         128.644069            -286.607238
#
#                                    Admission_Deposit
# case_id                                -1.713558e+06
# Hospital_code                           4.523662e+02
# City_Code_Hospital                     -1.191204e+02
# Available Extra Rooms in Hospital      -1.798160e+02
# Bed Grade                               6.273423e+01
# patientid                               8.964056e+04
# City_Code_Patient                       1.286441e+02
# Visitors with Patient                  -2.866072e+02
# Admission_Deposit                       1.168057e+06

# %% [markdown]
# HEATMAP

# %%
sns.heatmap(df.corr(),annot=True)
plt.title("correlation Matrix")
plt.show()

# %% [markdown]
# HISTOGRAM

# %%
df["Admission_Deposit"].hist(bins=10)
plt.title("Histogram for Admission_Deposit ")
plt.show()

# %%
df["Ward_Type"].hist(bins=10)
plt.title("Histogram for Ward_Type ")
plt.show()

# %%
df["patientid"].hist(bins=100)
plt.title("Histogram for patientid ")
plt.show()
